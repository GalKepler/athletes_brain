# %%
# Standard imports
from pathlib import Path
import pandas as pd
import numpy as np

# Import our refactored modules
from athletes_brain.fig1 import (
    Fig1Config,
    AthletesBrainDataLoader,
    GroupComparison,
    BrainPlotter,
    generate_figure1,
)

# Import specific functions for focused analysis
from athletes_brain.fig1.main import analyze_specific_comparison, get_most_significant_regions
# Out:
# 2025-08-31 11:14:25.778 | INFO     | athletes_brain.config:<module>:11 - PROJ_ROOT path is: /home/galkepler/Projects/athletes_brain

# %%
# Initialize configuration
config = Fig1Config()

config.METRICS = ["gm_vol", "adc"]
# Set up matplotlib configuration for consistent plots
config.setup_matplotlib_config()

# Display configuration
print(f"Atlas: {config.ATLAS}")
print(f"Metrics: {config.METRICS}")
print(
    f"Group labels: {config.CLIMBER_GROUP_LABEL}, {config.BJJ_GROUP_LABEL}, {config.CONTROL_GROUP_LABEL}"
)
print(f"P-value threshold: {config.P_THRESHOLD}")
print(f"Visualization range: [{config.VMIN}, {config.VMAX}]")
# Out:
# Atlas: schaefer2018tian2020_400_7
# Metrics: ['gm_vol', 'adc']
# Group labels: Climbing, Bjj, Control
# P-value threshold: 0.05
# Visualization range: [-5, 5]

# %%
FORCE = True
# Generate complete Figure 1
output_dir = Path("/media/storage/phd") / "athletes_brain" / "figures" / "learners"
# generate_figure1(output_dir=output_dir, config=config)

# %%
# Initialize data loader
data_loader = AthletesBrainDataLoader(config)

# Load all data
metric_data, parcels, nifti_path, nifti_matlab_path = data_loader.load_all_data()

print(f"Loaded {len(metric_data)} metrics")
print(f"Loaded {len(parcels)} brain parcels")
print(f"Metrics: {list(metric_data.keys())}")

metric_data = {
    key: val.drop(val[(~val["cs_valid"]) & ~val["learner"]].index)
    for key, val in metric_data.items()
}

# Display sample data (demographics)
d = metric_data["gm_vol"].drop_duplicates(subset=["subject_code"], keep="first")
print(f"Total N participants: {d.shape[0]}")
athletes = d[d["target"]]
climbers = athletes[athletes["group"] == config.CLIMBER_GROUP_LABEL]
bjjers = athletes[athletes["group"] == config.BJJ_GROUP_LABEL]

learners = d[d["learner"]]
climbers_learners = learners[learners["group"] == config.CLIMBER_GROUP_LABEL]
bjjers_learners = learners[learners["group"] == config.BJJ_GROUP_LABEL]

print(f"Total N athletes: {athletes.shape[0]}")
print(f"Total N climbers: {climbers.shape[0]}")
print(f"Total N BJJ practitioners: {bjjers.shape[0]}")
print(f"Total N learners: {learners.shape[0]}")
print(f"Total N climbers (learners): {climbers_learners.shape[0]}")
print(f"Total N BJJ practitioners (learners): {bjjers_learners.shape[0]}")
# Out:
# 2025-08-31 11:22:23.246 | INFO     | athletes_brain.fig1.data_loader:load_metric_data:48 - Loading metric data...
# 2025-08-31 11:22:23.247 | INFO     | athletes_brain.fig1.data_loader:load_metric_data:54 - Loading gm_vol data
# /home/galkepler/Projects/athletes_brain/athletes_brain/fig1/data_loader.py:57: DtypeWarning: Columns (1,6,7,8,9,10,11,12,68,74,78,79,80,81,82,84,85,86,87,92,93,94,95,96,97,99,113,115,116,121,122,123,124,125,132,133,134) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(self.processed_dir / f"{metric}.csv", index_col=0).reset_index(
# 2025-08-31 11:23:27.332 | INFO     | athletes_brain.fig1.data_loader:load_metric_data:82 - Loaded 1583098 records for gm_vol
# 2025-08-31 11:23:27.332 | INFO     | athletes_brain.fig1.data_loader:load_metric_data:54 - Loading adc data
# /home/galkepler/Projects/athletes_brain/athletes_brain/fig1/data_loader.py:57: DtypeWarning: Columns (16,23,24,25,26,27,33,39,43,44,45,46,47,49,50,51,52,57,58,59,60,61,62,64,78,80,81,86,87,88,89,96,97,98,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(self.processed_dir / f"{metric}.csv", index_col=0).reset_index(
# 2025-08-31 11:23:59.955 | INFO     | athletes_brain.fig1.data_loader:load_metric_data:82 - Loaded 1588092 records for adc
# 2025-08-31 11:23:59.955 | SUCCESS  | athletes_brain.fig1.data_loader:load_metric_data:84 - Successfully loaded 2 metrics
# 2025-08-31 11:23:59.955 | INFO     | athletes_brain.fig1.data_loader:load_atlas_data:32 - Loading atlas data for schaefer2018tian2020_400_7
# 2025-08-31 11:23:59.961 | INFO     | athletes_brain.fig1.data_loader:load_atlas_data:39 - Loaded 454 parcels from atlas
# Loaded 2 metrics
# Loaded 454 brain parcels
# Metrics: ['gm_vol', 'adc']
# Total N participants: 1685
# Total N athletes: 139
# Total N climbers: 80
# Total N BJJ practitioners: 51
# Total N learners: 243
# Total N climbers (learners): 116
# Total N BJJ practitioners (learners): 103

# %%
for _, df in metric_data.items():
    df["timestamp"] = pd.to_datetime(df["session_id"], format="%Y%m%d%H%M")

# %%
import math
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.stats.multitest import multipletests
from numpy.linalg import LinAlgError
from tqdm import tqdm


def _get_beta_and_vcov(res):
    """
    Return (beta_vec, vcov_mat, names_list) for fixed effects only,
    across MixedLM and OLS (incl. cluster-robust wrappers).
    """
    # Preferred path for MixedLM: use fixed effects only
    fe = getattr(res, "fe_params", None)
    if isinstance(fe, pd.Series):
        P = fe.values.astype(float)
        Vfull = res.cov_params()
        if isinstance(Vfull, pd.DataFrame):
            V = Vfull.loc[fe.index, fe.index].values
        else:
            V = np.asarray(Vfull)[: len(P), : len(P)]
        names = list(fe.index)
        return P, V, names

    # Generic path (OLS etc.)
    P = getattr(res, "params", None)
    V = res.cov_params()
    # names
    try:
        names = list(res.model.exog_names)
    except Exception:
        names = None

    if isinstance(P, pd.Series):
        names = list(P.index) if names is None else names
        P = P.values.astype(float)
    else:
        P = np.asarray(P, dtype=float).ravel()
        if names is None:
            names = [f"x{i}" for i in range(len(P))]

    V = V.values if isinstance(V, pd.DataFrame) else np.asarray(V, dtype=float)
    return P, V, names


def lincom(res, coefs, *, warn_missing=False):
    """
    Linear combo on a statsmodels result.
    coefs: dict {param_name: weight}
    Returns: (est, se, z, p, lo, hi)
    """
    P, V, names = _get_beta_and_vcov(res)
    name_to_idx = {n: i for i, n in enumerate(names)}
    L = np.zeros_like(P, dtype=float)

    missing = []
    for name, w in coefs.items():
        if name in name_to_idx:
            L[name_to_idx[name]] = w
        else:
            missing.append(name)

    if warn_missing and missing:
        print(f"[lincom] Missing params (treated as 0): {missing}\nAvailable: {names}")

    est = float(L @ P)
    var = float(L @ V @ L)
    se = np.sqrt(max(var, 0.0))
    z = est / se if se > 0 else np.nan
    # two-sided normal p:
    p = 2 * 0.5 * math.erfc(abs(z) / np.sqrt(2)) if se > 0 else np.nan
    lo, hi = est - 1.96 * se, est + 1.96 * se
    return est, se, z, p, lo, hi


def _sex_term(d):
    return " + C(sex)" if ("sex" in d.columns and d["sex"].nunique() > 1) else ""


def _tiv_term(metric: str):
    return " + tiv" if "vol" in str(metric).lower() else ""


def add_scaled_covariates(d: pd.DataFrame, metric: str) -> pd.DataFrame:
    d = d.copy()
    # Age: center, then square the centered term
    if "age_at_scan" in d.columns:
        d["age_c"] = d["age_at_scan"] - d["age_at_scan"].mean()
        d["age_c2"] = d["age_c"] ** 2
    else:
        d["age_c"] = d["age_c2"] = 0.0

    # TIV: z-score if present and used for 'vol' metrics
    if "tiv" in d.columns and "vol" in str(metric).lower():
        sd = d["tiv"].std(ddof=0)
        d["tiv_z"] = (d["tiv"] - d["tiv"].mean()) / (sd if sd and sd > 0 else 1.0)
    # else:
    #     d["tiv_z"] = 0.0

    return d


# ---------- primary Athlete vs Learner model ----------
def fit_roi_model(d, metric: str, time_variable: str = "time_months"):
    d = add_scaled_covariates(d, metric)
    d["tp_label"] = pd.Categorical(d["tp_label"], categories=["pre", "post"])
    d["condition"] = pd.Categorical(d["condition"], categories=["Athlete", "Learner"])
    if "sex" in d:
        d["sex"] = d["sex"].astype("category")

    if d["condition"].nunique() < 2:
        return None, "one_group_only"
    if d["subject_code"].nunique() < 3:
        return None, "too_few_subjects"

    sex_term = " + C(sex)" if ("sex" in d and d["sex"].nunique() > 1) else ""
    tiv_term = " + tiv_z" if ("vol" in str(metric).lower()) else ""

    formula = (
        f"y ~ {time_variable} * C(condition, levels=['Athlete','Learner'])"
        " + age_c + age_c2" + sex_term + tiv_term
    )
    try:
        m = smf.mixedlm(formula, data=d, groups=d["subject_code"]).fit(reml=True, maxiter=400)
        return m, "mixed"
    except (LinAlgError, ValueError):
        return None, "mixed_fail"
    # except (LinAlgError, ValueError):
    #     ols = smf.ols(formula, data=d).fit()
    #     return ols.get_robustcov_results(cov_type="cluster", groups=d["subject_code"]), "ols_cluster"


def extract_effects(res, time_variable: str = "time_months"):
    """Key effects with Athlete baseline."""
    is_mixed = hasattr(res, "random_effects") or hasattr(res, "cov_re")
    # p_post   = "C(tp_label, levels=['pre', 'post'])[T.post]"
    p_post = time_variable
    p_L = "C(condition, levels=['Athlete', 'Learner'])[T.Learner]"
    p_postxL = p_post + ":" + p_L

    out = {}
    est, se, z, p, lo, hi = lincom(res, {p_post: 1.0})
    out.update(dict(beta_post=est, se_post=se, z_post=z, p_post=p, lo_post=lo, hi_post=hi))

    est, se, z, p, lo, hi = lincom(res, {p_L: 1.0})
    out.update(
        dict(
            beta_learner_pre=est,
            se_learner_pre=se,
            z_learner_pre=z,
            p_learner_pre=p,
            lo_learner_pre=lo,
            hi_learner_pre=hi,
        )
    )

    est, se, z, p, lo, hi = lincom(res, {p_postxL: 1.0})
    out.update(
        dict(
            beta_postx_learner=est,
            se_postx_learner=se,
            z_postx_learner=z,
            p_postx_learner=p,
            lo_postx_learner=lo,
            hi_postx_learner=hi,
        )
    )

    est, se, z, p, lo, hi = lincom(res, {p_post: 1.0, p_postxL: 1.0})
    out.update(
        dict(
            beta_learner_post_change=est,
            se_learner_post_change=se,
            p_learner_post_change=p,
            lo_learner_post_change=lo,
            hi_learner_post_change=hi,
        )
    )

    out["model"] = "mixed" if is_mixed else "ols_cluster"
    out["converged"] = getattr(res, "converged", np.nan)
    return out


# ---------- learners-only: pre/post model ----------
def fit_learners_prepost(d, metric: str):
    dl = d.query("condition == 'Learner' and tp_label in ['pre', 'post']").copy()
    has_both = dl.groupby("subject_code")["tp_label"].transform(
        lambda s: {"pre", "post"}.issubset(set(s))
    )
    dl = dl[has_both]
    if dl["subject_code"].nunique() < 2:
        return None, "L_too_few_subjects"

    dl = add_scaled_covariates(dl, metric)
    if "sex" in dl:
        dl["sex"] = dl["sex"].astype("category")
    formula = (
        "y ~ C(tp_label, levels=['pre', 'post']) + age_c + age_c2"
        + (" + C(sex)" if ("sex" in dl and dl["sex"].nunique() > 1) else "")
        + (" + tiv_z" if ("vol" in str(metric).lower()) else "")
    )
    try:
        m = smf.mixedlm(formula, data=dl, groups=dl["subject_code"]).fit(reml=True, maxiter=400)
        status = "L_mixed"
    except (LinAlgError, ValueError):
        m = (
            smf.ols(formula, data=dl)
            .fit()
            .get_robustcov_results(cov_type="cluster", groups=dl["subject_code"])
        )
        status = "L_ols_cluster"

    # extract the pre→post effect within learners
    term = "C(tp_label, levels=['pre', 'post'])[T.post]"
    est, se, z, p, lo, hi = lincom(m, {term: 1.0})
    out = {
        "L_post_beta": est,
        "L_post_se": se,
        "L_post_z": z,
        "L_post_p": p,
        "L_post_lo": lo,
        "L_post_hi": hi,
        "L_model": "mixed" if status == "L_mixed" else "ols_cluster",
        "L_status": status,
    }
    return out, status


# ---------- learners-only: monthly slope model ----------
def fit_learners_slope(d, metric: str, time_variable: str = "time_months"):
    dl = d.query("condition == 'Learner' and tp_label in ['pre', 'post']").copy()
    has_both = dl.groupby("subject_code")["tp_label"].transform(
        lambda s: {"pre", "post"}.issubset(set(s))
    )
    dl = dl[has_both]
    if dl["subject_code"].nunique() < 2:
        return None, "Lsl_too_few_subjects"

    dl = add_scaled_covariates(dl, metric)
    if "sex" in dl:
        dl["sex"] = dl["sex"].astype("category")
    formula = (
        f"y ~ {time_variable} + age_c + age_c2"
        + (" + C(sex)" if ("sex" in dl and dl["sex"].nunique() > 1) else "")
        + (" + tiv_z" if ("vol" in str(metric).lower()) else "")
    )
    try:
        m = smf.mixedlm(formula, data=dl, groups=dl["subject_code"]).fit(reml=True, maxiter=400)
        status = "Lsl_mixed"
    except (LinAlgError, ValueError):
        m = (
            smf.ols(formula, data=dl)
            .fit()
            .get_robustcov_results(cov_type="cluster", groups=dl["subject_code"])
        )
        status = "Lsl_ols_cluster"
    # extract time_months effect as before...

    term = time_variable
    est, se, z, p, lo, hi = lincom(m, {term: 1.0})
    out = {
        "L_slope_month_beta": est,
        "L_slope_month_se": se,
        "L_slope_month_z": z,
        "L_slope_month_p": p,
        "L_slope_month_lo": lo,
        "L_slope_month_hi": hi,
        "L_slope_model": "mixed" if status == "Lsl_mixed" else "ols_cluster",
        "L_slope_status": status,
    }
    return out, status

# %%
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
import statsmodels.formula.api as smf


def _fit_mixed_or_ols(formula: str, d: pd.DataFrame):
    """Try MixedLM; on failure, fall back to OLS with subject-clustered SEs."""
    try:
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=ConvergenceWarning)
            m = smf.mixedlm(formula, data=d, groups=d["subject_code"]).fit(
                reml=True, method="lbfgs", maxiter=500
            )
        return m, "mixed"
    except Exception:
        ols = smf.ols(formula, data=d).fit()
        return (
            ols.get_robustcov_results(cov_type="cluster", groups=d["subject_code"]),
            "ols_cluster",
        )


def fit_roi_model_both(d: pd.DataFrame, metric: str, include_sport: bool = False):
    """
    Fits two parameterizations on the same ROI df:
      (1) Slope model:     y ~ time_months * condition + covars
      (2) Factor model:    y ~ post(pre/post) * condition + covars
    Returns dict with models and status flags.
    """
    out = {}

    # scale covariates (age_c, age_c2, tiv_z)
    d = add_scaled_covariates(d, metric).copy()

    # categories
    d["tp_label"] = pd.Categorical(d["tp_label"], categories=["pre", "post"])
    d["condition"] = pd.Categorical(d["condition"], categories=["Athlete", "Learner"])
    if "sex" in d:
        d["sex"] = d["sex"].astype("category")
    if "sport" in d:
        d["sport"] = d["sport"].astype("category")

    # minimal sample checks
    if d["condition"].nunique() < 2:
        return {
            "status_slope": "one_group_only",
            "status_factor": "one_group_only",
            "model_slope": None,
            "model_factor": None,
        }
    if d["subject_code"].nunique() < 3:
        return {
            "status_slope": "too_few_subjects",
            "status_factor": "too_few_subjects",
            "model_slope": None,
            "model_factor": None,
        }

    # optional terms
    sex_term = " + C(sex)" if ("sex" in d and d["sex"].nunique() > 1) else ""
    tiv_term = " + tiv_z" if ("vol" in str(metric).lower()) else ""
    sport_term = (
        " + C(sport)" if (include_sport and "sport" in d and d["sport"].nunique() > 1) else ""
    )

    # 1) slope model
    formula_slope = (
        "y ~ time_months * C(condition, levels=['Athlete','Learner'])"
        " + age_c" + sex_term + tiv_term + sport_term
    )
    m_slope, status_slope = _fit_mixed_or_ols(formula_slope, d)
    out["model_slope"], out["status_slope"] = m_slope, status_slope

    # 2) factor (pre/post) model
    formula_factor = (
        "y ~ C(tp_label, levels=['pre', 'post']) * C(condition, levels=['Athlete','Learner'])"
        " + age_c" + sex_term + tiv_term + sport_term
    )
    m_factor, status_factor = _fit_mixed_or_ols(formula_factor, d)
    out["model_factor"], out["status_factor"] = m_factor, status_factor

    return out


def extract_effects_both(model_slope, model_factor):
    """
    Pulls the key estimates (athlete baseline, interaction, learner totals),
    plus baseline (pre) Learner–Athlete differences in both parameterizations.
    Returns a flat dict ready to assign into your stats row.
    """
    out = {}

    # ---- slope model effects ----
    if model_slope is not None:
        # Athlete monthly slope (baseline)
        est = lincom(model_slope, {"time_months": 1.0})
        out.update({f"slope_{k}": v for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)})

        # Interaction: slope × Learner (difference in monthly slope L - A)
        name_int = "time_months:C(condition, levels=['Athlete', 'Learner'])[T.Learner]"
        est = lincom(model_slope, {name_int: 1.0})
        out.update(
            {f"slope_interaction_{k}": v for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)}
        )

        # Learner monthly slope (sum)
        est = lincom(model_slope, {"time_months": 1.0, name_int: 1.0})
        out.update(
            {f"slope_x_learner_{k}": v for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)}
        )

        # Baseline (t=0) Learner–Athlete difference
        name_L = "C(condition, levels=['Athlete', 'Learner'])[T.Learner]"
        est = lincom(model_slope, {name_L: 1.0})
        out.update(
            {f"slope_learner_pre_{k}": v for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)}
        )

    # ---- factor model effects ----
    if model_factor is not None:
        post = "C(tp_label, levels=['pre', 'post'])[T.post]"
        intL = post + ":" + "C(condition, levels=['Athlete', 'Learner'])[T.Learner]"
        preL = "C(condition, levels=['Athlete', 'Learner'])[T.Learner]"

        # Athlete pre→post change (baseline)
        est = lincom(model_factor, {post: 1.0})
        out.update({f"factor_{k}": v for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)})

        # Interaction (DiD): extra pre→post in Learners vs Athletes
        est = lincom(model_factor, {intL: 1.0})
        out.update(
            {
                f"factor_interaction_{k}": v
                for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)
            }
        )

        # Learner pre→post change (sum)
        est = lincom(model_factor, {post: 1.0, intL: 1.0})
        out.update(
            {f"factor_x_learner_{k}": v for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)}
        )

        # Baseline (pre) Learner–Athlete difference
        est = lincom(model_factor, {preL: 1.0})
        out.update(
            {
                f"factor_learner_pre_{k}": v
                for k, v in zip(["est", "se", "z", "p", "lo", "hi"], est)
            }
        )

    return out

# %%
# ---------- your existing prep ----------
from notebooks.learners.roi_prep import (
    PrepConfig,
    prepare_roi_longitudinal,
    prepost_ancova_table,
    delta_change_table,
)

cfg = PrepConfig(restrict_roles=False, min_scans_per_subject=1)

# Columns to store (primary + learners-only)
add_cols = [
    "n_subjects",
    "n_athlete",
    "n_learner",
    "n_pairs_athlete",
    "n_pairs_learner",
    "L_model",
    "L_status",
    "L_slope_model",
    "L_slope_status",
    "status_slope",
    "status_factor",
    "slope_est",
    "slope_se",
    "slope_z",
    "slope_p",
    "slope_lo",
    "slope_hi",
    "slope_x_learner_est",
    "slope_x_learner_se",
    "slope_x_learner_z",
    "slope_x_learner_p",
    "slope_x_learner_lo",
    "slope_x_learner_hi",
    "factor_est",
    "factor_se",
    "factor_z",
    "factor_p",
    "factor_lo",
    "factor_hi",
    "factor_x_learner_est",
    "factor_x_learner_se",
    "factor_x_learner_z",
    "factor_x_learner_p",
    "factor_x_learner_lo",
    "factor_x_learner_hi",
    "slope_interaction_est",
    "slope_interaction_se",
    "slope_interaction_z",
    "slope_interaction_p",
    "slope_interaction_lo",
    "slope_interaction_hi",
    "factor_interaction_est",
    "factor_interaction_se",
    "factor_interaction_z",
    "factor_interaction_p",
    "factor_interaction_lo",
    "factor_interaction_hi",
    "L_post_beta",
    "L_post_se",
    "L_post_z",
    "L_post_p",
    "L_post_lo",
    "L_post_hi",
    "L_slope_month_beta",
    "L_slope_month_se",
    "L_slope_month_z",
    "L_slope_month_p",
    "L_slope_month_lo",
    "L_slope_month_hi",
]

families = [
    ["factor_p", "factor_interaction_p", "factor_x_learner_p", "factor_learner_pre_p"],
    ["slope_p", "slope_interaction_p", "slope_x_learner_p", "slope_learner_pre_p"],
    ["L_post_p"],
    ["L_slope_month_p"],
]

results = {}
all_rows = []

# FORCE = True

for metric, df in metric_data.items():
    # if metric != "adc":
    #     continue
    for group in ["all", "climbing", "bjj"]:
        data_destination = output_dir / group / "active" / metric / "stats.csv"
        data_destination.parent.mkdir(parents=True, exist_ok=True)
        if not FORCE and data_destination.exists():
            stats = pd.read_csv(data_destination)
            all_rows.append(stats)
            continue

        # if group != "Climbing":
        #     continue
        if group != "all":
            group_df = df[df["group"].str.lower() == group]
        else:
            group_df = df.copy()
        stats = parcels.copy()
        for c in add_cols:
            if c not in stats.columns:
                stats[c] = np.nan

        for i, prow in tqdm(
            parcels.iterrows(), total=parcels.shape[0], desc=f"{metric} · {group}"
        ):
            # if i != 174:
            #     continue
            region = prow["index"]
            roi_df = group_df[group_df["index"] == region]
            tidy = prepare_roi_longitudinal(roi_df, cfg)
            tidy = tidy[tidy["time_months"] < 12 * 2]
            # --- keep only pre/post; keep subjects that have BOTH pre & post
            d = tidy.loc[tidy["tp_label"].isin(["pre", "post"])].copy()
            d = d.loc[d["sport"].str.lower().isin(["bjj", "climbing"])].copy()
            has_both = d.groupby("subject_code")["tp_label"].transform(
                lambda s: {"pre", "post"}.issubset(set(s))
            )
            d = d[has_both].copy()
            if d.empty:
                stats.loc[i, "status"] = "no_pairs"
                continue

            # counts
            n_sub = d["subject_code"].nunique()
            n_by_cond = (
                d.groupby("condition")["subject_code"].nunique()
                if not d.empty
                else pd.Series(dtype=int)
            )
            n_learn = int(n_by_cond.get("Learner", 0))
            n_ath = int(n_by_cond.get("Athlete", 0))

            # pairs by condition (subjects with both labels)
            both = (
                d.groupby(["subject_code", "condition"])["tp_label"]
                .nunique()
                .reset_index(name="n")
            )
            n_pairs_ath = int(
                (both.query("condition=='Athlete' and n==2")["subject_code"]).nunique()
            )
            n_pairs_learner = int(
                (both.query("condition=='Learner' and n==2")["subject_code"]).nunique()
            )

            # # compute change scores (delta metric)
            # pre = d.loc[d["tp_label"]=="pre", ["subject_code","y","scan_dt"]].rename(columns={"y":"y_pre","scan_dt":"t_pre"})
            # post= d.loc[d["tp_label"]=="post",["subject_code","y","scan_dt"]].rename(columns={"y":"y_post","scan_dt":"t_post"})

            # df_diff = (post
            #     .merge(pre, on="subject_code", how="inner")
            #     .assign(delta=lambda x: x.y_post - x.y_pre,
            #             relative_delta=lambda x: x.delta / x.y_pre.replace(0, np.nan),
            #             delta_days=lambda x: (x.t_post - x.t_pre).dt.days))

            stats.loc[
                i, ["n_subjects", "n_learner", "n_athlete", "n_pairs_learner", "n_pairs_athlete"]
            ] = [n_sub, n_learn, n_ath, n_pairs_learner, n_pairs_ath]

            # ----- primary Athlete vs Learner model -----
            if n_pairs_ath < 1 or n_pairs_learner < 1:
                stats.loc[i, "status"] = "insufficient_pairs_primary"
            else:
                # result_models = fit_roi_model_both(d, metric=metric)
                result_models = fit_roi_model_both(
                    d, metric=metric, include_sport=(group == "all")
                )
                stats.loc[i, "status_slope"] = result_models.get("status_slope")
                stats.loc[i, "status_factor"] = result_models.get("status_factor")
                out = extract_effects_both(
                    result_models.get("model_slope"), result_models.get("model_factor")
                )
                for k, v in out.items():
                    stats.loc[i, k] = v

                # res, status = fit_roi_model(d, metric=metric)
                # stats.loc[i, "status"] = status
                # if res is not None:
                #     eff = extract_effects(res)
                #     for k, v in eff.items():
                #         stats.loc[i, k] = v
            # break

            # ----- learners-only pre/post -----
            L_out, L_status = fit_learners_prepost(d, metric=metric)
            if L_out is not None:
                for k, v in L_out.items():
                    stats.loc[i, k] = v
            else:
                stats.loc[i, "L_status"] = L_status

            # ----- learners-only slope (monthly) -----
            Lsl_out, Lsl_status = fit_learners_slope(d, metric=metric)
            if Lsl_out is not None:
                for k, v in Lsl_out.items():
                    stats.loc[i, k] = v
            else:
                stats.loc[i, "L_slope_status"] = Lsl_status
            # if i == 174:
            #     raise ValueError("debug")
            # break
        # break
        # FDR across regions (per metric×group) for key p-values
        for fam in families:
            for pcol in fam:
                if pcol in stats:
                    qcol = pcol[:-2] + "_q"
                    mask = stats[pcol].notna()
                    if mask.any():
                        stats.loc[mask, qcol] = multipletests(
                            stats.loc[mask, pcol], method="fdr_bh"
                        )[1]

        # annotate and stash
        stats["metric"] = metric
        stats["sport_group"] = group
        stats.to_csv(data_destination, index=False)
        all_rows.append(stats)


# Final region-wise table
region_results = pd.concat(all_rows, ignore_index=True)
# Out:
# gm_vol · all:   0%|          | 0/454 [00:00<?, ?it/s]/tmp/ipykernel_3415801/795509130.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_slope"] = result_models.get("status_slope")
# /tmp/ipykernel_3415801/795509130.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_factor"] = result_models.get("status_factor")
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'L_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Lsl_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# gm_vol · all: 100%|██████████| 454/454 [15:57<00:00,  2.11s/it]
# gm_vol · climbing:   0%|          | 0/454 [00:00<?, ?it/s]/tmp/ipykernel_3415801/795509130.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_slope"] = result_models.get("status_slope")
# /tmp/ipykernel_3415801/795509130.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_factor"] = result_models.get("status_factor")
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'L_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Lsl_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# gm_vol · climbing: 100%|██████████| 454/454 [06:24<00:00,  1.18it/s]
# gm_vol · bjj:   0%|          | 0/454 [00:00<?, ?it/s]/tmp/ipykernel_3415801/795509130.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_slope"] = result_models.get("status_slope")
# /tmp/ipykernel_3415801/795509130.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_factor"] = result_models.get("status_factor")
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'L_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Lsl_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# gm_vol · bjj:  94%|█████████▎| 425/454 [04:20<00:13,  2.19it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# gm_vol · bjj: 100%|██████████| 454/454 [04:33<00:00,  1.66it/s]
# adc · all:   0%|          | 0/454 [00:00<?, ?it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /tmp/ipykernel_3415801/795509130.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_slope"] = result_models.get("status_slope")
# /tmp/ipykernel_3415801/795509130.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ols_cluster' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, "status_factor"] = result_models.get("status_factor")
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'L_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# /tmp/ipykernel_3415801/795509130.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Lsl_mixed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   stats.loc[i, k] = v
# adc · all:   0%|          | 1/454 [00:00<06:13,  1.21it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:   0%|          | 2/454 [00:01<05:17,  1.42it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:   1%|          | 3/454 [00:02<05:18,  1.42it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:   1%|          | 4/454 [00:03<06:29,  1.16it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:   1%|          | 5/454 [00:04<06:57,  1.07it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:
/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  13%|█▎        | 61/454 [01:59<14:37,  2.23s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  14%|█▎        | 62/454 [02:01<14:08,  2.16s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  14%|█▍        | 63/454 [02:03<13:51,  2.13s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  14%|█▍        | 64/454 [02:05<13:25,  2.07s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  14%|█▍        | 65/454 [02:08<13:30,  2.08s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  15%|█▍        | 66/454 [02:10<14:01,  2.17s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  15%|█▍        | 67/454 [02:12<14:11,  2.20s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  15%|█▍        | 68/454 [02:14<14:18,  2.22s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · all:  15%|█▌        | 69/454 [02:16<12:28,  1.94s/it]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# ...
# adc · bjj:  94%|█████████▍| 429/454 [03:09<00:09,  2.78it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  95%|█████████▍| 430/454 [03:09<00:08,  2.67it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  95%|█████████▍| 431/454 [03:10<00:08,  2.61it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  95%|█████████▌| 432/454 [03:10<00:08,  2.56it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  95%|█████████▌| 433/454 [03:10<00:08,  2.58it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  96%|█████████▌| 434/454 [03:11<00:08,  2.33it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  96%|█████████▌| 435/454 [03:11<00:07,  2.45it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  96%|█████████▌| 436/454 [03:12<00:07,  2.53it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  96%|█████████▋| 437/454 [03:12<00:06,  2.51it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  96%|█████████▋| 438/454 [03:12<00:06,  2.37it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  97%|█████████▋| 439/454 [03:13<00:06,  2.50it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  97%|█████████▋| 440/454 [03:13<00:05,  2.59it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  97%|█████████▋| 441/454 [03:13<00:04,  2.77it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  97%|█████████▋| 442/454 [03:14<00:04,  2.77it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  98%|█████████▊| 443/454 [03:14<00:03,  2.88it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  98%|█████████▊| 444/454 [03:14<00:03,  3.15it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  98%|█████████▊| 445/454 [03:15<00:02,  3.32it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  98%|█████████▊| 446/454 [03:15<00:02,  3.18it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  98%|█████████▊| 447/454 [03:15<00:02,  3.10it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  99%|█████████▊| 448/454 [03:16<00:01,  3.30it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  99%|█████████▉| 449/454 [03:16<00:01,  3.45it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  99%|█████████▉| 450/454 [03:16<00:01,  3.05it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj:  99%|█████████▉| 451/454 [03:17<00:00,  3.01it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj: 100%|█████████▉| 452/454 [03:17<00:00,  3.23it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj: 100%|█████████▉| 453/454 [03:17<00:00,  3.05it/s]/home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# adc · bjj: 100%|██████████| 454/454 [03:18<00:00,  2.29it/s]

# %%
# import seaborn as sns
# i = stats["factor_x_learner_p"].idxmin()
# # i = 125

# region = stats.loc[i, "index"]

# roi_df = group_df[group_df["index"] == region]
# tidy = prepare_roi_longitudinal(roi_df, cfg)
# tidy = tidy[tidy["time_months"] < 12*2]
# # --- keep only pre/post; keep subjects that have BOTH pre & post
# # d = tidy.loc[tidy["tp_label"].isin(["pre", "post"])].copy()
# d = tidy.loc[tidy["sport"].str.lower().isin(["bjj", "climbing"])].copy()

# # # counts
# # n_sub = d["subject_code"].nunique()
# # n_by_cond = d.groupby("condition")["subject_code"].nunique() if not d.empty else pd.Series(dtype=int)
# # n_learn   = int(n_by_cond.get("Learner", 0))
# # n_ath     = int(n_by_cond.get("Athlete", 0))

# # # pairs by condition (subjects with both labels)
# # both = d.groupby(["subject_code","condition"])["tp_label"].nunique().reset_index(name="n")
# # n_pairs_ath     = int((both.query("condition=='Athlete' and n==2")["subject_code"]).nunique())
# # n_pairs_learner = int((both.query("condition=='Learner' and n==2")["subject_code"]).nunique())

# # # compute change scores (delta metric)
# # has_both = d.groupby("subject_code")["tp_label"].transform(lambda s: {"pre","post"}.issubset(set(s)))
# # d_both = d[has_both].copy()
# # d_before = d_both[d_both["tp_label"] == "pre"]
# # d_after = d_both[d_both["tp_label"] == "post"]
# # df_diff = d_after.copy()
# # df_diff["delta"] = df_diff["y"] - d_before["y"].values
# # df_diff["relative_delta"] = df_diff["delta"] / d_before["y"].values
# # df_diff["delta_days"] = (d_after["scan_dt"] - d_before["scan_dt"].values).dt.days

# # stats.loc[i, ["n_subjects","n_learner","n_athlete","n_pairs_learner","n_pairs_athlete"]] = \
# #     [n_sub, n_learn, n_ath, n_pairs_learner, n_pairs_ath]

# # # ----- primary Athlete vs Learner model -----
# # if n_pairs_ath < 1 or n_pairs_learner < 1:
# #     stats.loc[i, "status"] = "insufficient_pairs_primary"
# # else:
# #     result_models = fit_roi_model_both(d, metric=metric)
# #     stats.loc[i, "status_slope"] = result_models.get("status_slope")
# #     stats.loc[i, "status_factor"] = result_models.get("status_factor")
# #     out = extract_effects_both(result_models.get("model_slope"), result_models.get("model_factor"))
# # 2) Keep subjects that have BOTH a pre and a post
# # has_both = d.groupby("subject_code")["tp_label"].transform(
# #     lambda s: {"pre", "post"}.issubset(set(s))
# # )
# # d = d[has_both].copy()

# import matplotlib.pyplot as plt

# fig, axes = plt.subplots(1,2, figsize=(20,6), sharex=True, sharey=True)

# for ax,condition in zip(axes, ["Athlete", "Learner"]):
#     ax = sns.lineplot(d[d["condition"] == condition], x="tp_label", y="y", ax=ax,
#                     #   hue="subject_code", legend=False
#                       )
#     ax.set_title(condition)

# %%
# # 2) Keep subjects that have BOTH a pre and a post
# # has_both = d.groupby("subject_code")["tp_label"].transform(
# #     lambda s: {"pre", "post"}.issubset(set(s))
# # )
# # d = d[has_both].copy()

# import matplotlib.pyplot as plt

# fig, axes = plt.subplots(1,2, figsize=(20,6), sharex=True, sharey=True)

# for ax,condition in zip(axes, ["Athlete", "Learner"]):
#     ax = sns.lineplot(d[d["condition"] == condition], x="tp_label", y="y", ax=ax,
#                     #   hue="subject_code", legend=False
#                       )
#     ax.set_title(condition)
# region_results
# (region_results[[col for col in region_results.columns if col.endswith("_q")]] < 0.05).sum()
# vis_df = region_results[(region_results["metric"] == metric) & (region_results["sport_group"].str.lower() == "bjj")]
# vis_df.sort_values("slope_learner_pre_p")["slope_learner_pre_q"]

# %%
import matplotlib.pyplot as plt

# visualize
metrics = ["gm_vol", "adc"]
analysis_levels = [
    "athletes_vs_controls",
    "climbing_vs_controls",
    "bjj_vs_controls",
    "climbing_vs_bjj",
]
# analysis_levels = ["climbing_vs_bjj"]
value_column = "r_partial"
vmin = -5
vmax = 5

fdr_corrected = True
# sport = "all"
old_format = False

# for contrast in ["slope_learner_pre", "factor_learner_pre", "slope","slope_x_learner","factor","factor_x_learner","slope_interaction","factor_interaction","L_post","L_slope_month"]:
for contrast in ["slope_x_learner", "factor_x_learner", "slope_interaction", "factor_interaction"]:
    contrast_name = contrast.replace("_p", "_q") if old_format else contrast
    for sport in ["all", "climbing", "bjj"]:
        for metric in metrics:
            fdr_label = "fdr_corrected" if fdr_corrected else "uncorrected"
            metric_dir = output_dir / sport / "active" / metric / contrast / fdr_label
            metric_dir.mkdir(parents=True, exist_ok=True)
            vis_df = region_results[
                (region_results["metric"] == metric)
                & (region_results["sport_group"].str.lower() == sport)
            ]

            vis_config = Fig1Config()
            vis_config.VMIN = vmin
            vis_config.VMAX = vmax

            #     break
            # break
            plotter = BrainPlotter(vis_config)

            plotter.plot_single_metric(
                results_df=vis_df,
                metric_key=f"{metric}_{sport}_{contrast}",
                output_dir=metric_dir,
                p_column=f"{contrast_name}_q" if fdr_corrected else f"{contrast_name}_p",
                value_column=f"{contrast_name}_z",
            )
            plt.close("all")
        #     break
        # break
# Out:
# 2025-08-31 12:08:36.942 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for gm_vol_all_slope_x_learner
# 2025-08-31 12:08:36.942 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-31 12:08:36.945 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-31 12:08:36.946 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for slope_x_learner_z
# 2025-08-31 12:08:36.966 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-31 12:08:36.966 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-31 12:08:36.977 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-31 12:08:37.748 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/active/gm_vol/slope_x_learner/fdr_corrected/left_gm_vol_all_slope_x_learner.png
# 2025-08-31 12:08:37.748 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-31 12:08:38.493 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/active/gm_vol/slope_x_learner/fdr_corrected/right_gm_vol_all_slope_x_learner.png
# 2025-08-31 12:08:38.494 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-31 12:08:38.494 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-31 12:08:38.971 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/active/gm_vol/slope_x_learner/fdr_corrected/subcort_gm_vol_all_slope_x_learner_L.png
# 2025-08-31 12:08:38.971 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-31 12:08:39.692 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/active/gm_vol/slope_x_learner/fdr_corrected/subcort_gm_vol_all_slope_x_learner_R.png
# 2025-08-31 12:08:39.692 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for gm_vol_all_slope_x_learner
# 2025-08-31 12:08:39.694 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for adc_all_slope_x_learner
# 2025-08-31 12:08:39.694 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-31 12:08:39.696 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-31 12:08:39.697 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for slope_x_learner_z
# 2025-08-31 12:08:39.709 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-31 12:08:39.710 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-31 12:08:39.717 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-31 12:08:40.473 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/active/adc/slope_x_learner/fdr_corrected/left_adc_all_slope_x_learner.png
# 2025-08-31 12:08:40.473 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-31 12:08:41.225 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/active/adc/slope_x_learner/fdr_corrected/right_adc_all_slope_x_learner.png
# 2025-08-31 12:08:41.225 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-31 12:08:41.225 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-31 12:08:41.729 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/active/adc/slope_x_learner/fdr_corrected/subcort_adc_all_slope_x_learner_L.png
# 2025-08-31 12:08:41.729 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-31 12:08:42.447 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/active/adc/slope_x_learner/fdr_corrected/subcort_adc_all_slope_x_learner_R.png
# 2025-08-31 12:08:42.447 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for adc_all_slope_x_learner
# 2025-08-31 12:08:42.449 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for gm_vol_climbing_slope_x_learner
# 2025-08-31 12:08:42.449 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-31 12:08:42.451 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-31 12:08:42.451 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for slope_x_learner_z
# 2025-08-31 12:08:42.463 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-31 12:08:42.463 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-31 12:08:42.471 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-31 12:08:43.206 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/gm_vol/slope_x_learner/fdr_corrected/left_gm_vol_climbing_slope_x_learner.png
# 2025-08-31 12:08:43.206 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-31 12:08:43.955 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/gm_vol/slope_x_learner/fdr_corrected/right_gm_vol_climbing_slope_x_learner.png
# 2025-08-31 12:08:43.955 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-31 12:08:43.956 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-31 12:08:44.431 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/gm_vol/slope_x_learner/fdr_corrected/subcort_gm_vol_climbing_slope_x_learner_L.png
# 2025-08-31 12:08:44.431 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-31 12:08:45.139 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/gm_vol/slope_x_learner/fdr_corrected/subcort_gm_vol_climbing_slope_x_learner_R.png
# 2025-08-31 12:08:45.140 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for gm_vol_climbing_slope_x_learner
# 2025-08-31 12:08:45.142 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for adc_climbing_slope_x_learner
# 2025-08-31 12:08:45.142 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-31 12:08:45.144 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-31 12:08:45.144 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for slope_x_learner_z
# 2025-08-31 12:08:45.156 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-31 12:08:45.157 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-31 12:08:45.164 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-31 12:08:45.897 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/adc/slope_x_learner/fdr_corrected/left_adc_climbing_slope_x_learner.png
# 2025-08-31 12:08:45.897 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-31 12:08:46.682 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/adc/slope_x_learner/fdr_corrected/right_adc_climbing_slope_x_learner.png
# 2025-08-31 12:08:46.683 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-31 12:08:46.683 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-31 12:08:47.168 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/climbing/active/adc/slope
| INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/bjj/active/adc/factor_interaction/fdr_corrected/subcort_adc_bjj_factor_interaction_R.png
# 2025-08-31 12:09:42.812 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for adc_bjj_factor_interaction

# %%
import os

sport = "climbing"
fdr_label = "fdr_corrected"
contrast = "slope_x_learner"
metric = "adc"

cmd_template = "shotwell /media/storage/phd/athletes_brain/figures/learners/{sport}/active/{metric}/{contrast}/{fdr_label}/left_{metric}_{sport}_{contrast}.png"

os.system(cmd_template.format(sport=sport, contrast=contrast, metric=metric, fdr_label=fdr_label))
# Out:
# ** Message: 12:09:42.868: main.vala:507: Starting session with system profile
# 0

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
import nibabel as nib
from nilearn import plotting

metric = "adc"
sport = "climbing"

contrast = "factor_interaction"

df_vis = region_results[
    (region_results["metric"] == metric) & (region_results["sport_group"].str.lower() == sport)
]
df_vis.index = parcels.index
# Load atlas

atlas = nib.load(nifti_matlab_path)
data = np.round(atlas.get_fdata())

# replace rois with the corresponding value
for i, row in tqdm(parcels.iterrows()):
    idx = int(row[config.REGION_COL])
    pval = df_vis.loc[i, f"{contrast}_p"]
    val = df_vis.loc[i, f"{contrast}_z"]
    data[data == idx] = val if pval < 0.05 else np.nan

atlas_mod = nib.Nifti1Image(data, atlas.affine, atlas.header)
# Out:
# 454it [00:07, 59.95it/s]

# %%
df_vis[df_vis["network"] == "subcortex"].sort_values(by=[f"{contrast}_p"], ascending=True)
# Out:
#      index            name    base_name  \
# 425    426          pGP-rh          pGP
# 432    433     HIP-body-lh     HIP-body
# 424    425     NAc-core-rh     NAc-core
# 444    445       CAU-DA-lh       CAU-DA
# 405    406     HIP-body-rh     HIP-body
# 417    418       CAU-DA-rh       CAU-DA
# 410    411      THA-DAm-rh      THA-DAm
# 400    401  HIP-head-m1-rh  HIP-head-m1
# 402    403     THA-VAip-rh     THA-VAip
# 431    432   HIP-head-l-lh   HIP-head-l
# 415    416       PUT-DP-rh       PUT-DP
# 443    444       CAU-VA-lh       CAU-VA
# 401    402  HIP-head-m2-rh  HIP-head-m2
# 449    450       THA-DP-lh       THA-DP
# 430    431     THA-VAia-lh     THA-VAia
# 436    437      THA-VAs-lh      THA-VAs
# 441    442       PUT-VP-lh       PUT-VP
# 437    438      THA-DAm-lh      THA-DAm
# 406    407     HIP-tail-rh     HIP-tail
# 445    446     CAU-body-lh     CAU-body
# 452    453          pGP-lh          pGP
# 429    430     THA-VAip-lh     THA-VAip
# 423    424    NAc-shell-rh    NAc-shell
# 419    420     CAU-tail-rh     CAU-tail
# 434    435      THA-VPm-lh      THA-VPm
# 451    452     NAc-core-lh     NAc-core
# 420    421         lAMY-rh         lAMY
# 404    405   HIP-head-l-rh   HIP-head-l
# 413    414       PUT-DA-rh       PUT-DA
# 421    422         mAMY-rh         mAMY
# 418    419     CAU-body-rh     CAU-body
# 407    408      THA-VPm-rh      THA-VPm
# 442    443       PUT-DP-lh       PUT-DP
# 448    449         mAMY-lh         mAMY
# 427    428  HIP-head-m1-lh  HIP-head-m1
# 412    413       PUT-VA-rh       PUT-VA
# 435    436      THA-VPl-lh      THA-VPl
# 414    415       PUT-VP-rh       PUT-VP
# 416    417       CAU-VA-rh       CAU-VA
# 411    412      THA-DAl-rh      THA-DAl
# 426    427          aGP-rh          aGP
# 409    410      THA-VAs-rh      THA-VAs
# 403    404     THA-VAia-rh     THA-VAia
# 433    434     HIP-tail-lh     HIP-tail
# 408    409      THA-VPl-rh      THA-VPl
# 446    447     CAU-tail-lh     CAU-tail
# 428    429  HIP-head-m2-lh  HIP-head-m2
# 447    448         lAMY-lh         lAMY
# 439    440       PUT-VA-lh       PUT-VA
# 438    439      THA-DAl-lh      THA-DAl
# 450    451    NAc-shell-lh    NAc-shell
# 453    454          aGP-lh          aGP
# 422    423       THA-DP-rh       THA-DP
# 440    441       PUT-DA-lh       PUT-DA
#
#                                             Label Name    network  \
# 425                           Pallidum, posterior part  subcortex
# 432                                   Hippocampus body  subcortex
# 424                            Nucleus Accumbens, core  subcortex
# 444                       Caudate, dorso-anterior part  subcortex
# 405                                   Hippocampus body  subcortex
# 417                       Caudate, dorso-anterior part  subcortex
# 410               Thalamus, medial dorso-anterior part  subcortex
# 400                  Hippocampus head, medial division  subcortex
# 402  Thalamus, inferior ventro-anterior part, poste...  subcortex
# 431                 Hippocampus head, lateral division  subcortex
# 415                      Putamen, dorso-posterior part  subcortex
# 443                      Caudate, ventro-anterior part  subcortex
# 401                  Hippocampus head, medial division  subcortex
# 449                     Thalamus, dorso-posterior part  subcortex
# 430  Thalamus, inferior ventro-anterior part, anter...  subcortex
# 436            Thalamus, superior ventro-anterior part  subcortex
# 441                     Putamen, ventro-posterior part  subcortex
# 437               Thalamus, medial dorso-anterior part  subcortex
# 406                                   Hippocampus tail  subcortex
# 445                                       Caudate body  subcortex
# 452                           Pallidum, posterior part  subcortex
# 429  Thalamus, inferior ventro-anterior part, poste...  subcortex
# 423                           Nucleus Accumbens, shell  subcortex
# 419                                       Caudate tail  subcortex
# 434             Thalamus, medial ventro-posterior part  subcortex
# 451                            Nucleus Accumbens, core  subcortex
# 420                          Amygdala, lateral nucleus  subcortex
# 404                 Hippocampus head, lateral division  subcortex
# 413                       Putamen, dorso-anterior part  subcortex
# 421                           Amygdala, medial nucleus  subcortex
# 418                                       Caudate body  subcortex
# 407             Thalamus, medial ventro-posterior part  subcortex
# 442                      Putamen, dorso-posterior part  subcortex
# 448                           Amygdala, medial nucleus  subcortex
# 427                  Hippocampus head, medial division  subcortex
# 412                      Putamen, ventro-anterior part  subcortex
# 435            Thalamus, lateral ventro-posterior part  subcortex
# 414                     Putamen, ventro-posterior part  subcortex
# 416                      Caudate, ventro-anterior part  subcortex
# 411              Thalamus, lateral dorso-anterior part  subcortex
# 426                            Pallidum, anterior part  subcortex
# 409            Thalamus, superior ventro-anterior part  subcortex
# 403  Thalamus, inferior ventro-anterior part, anter...  subcortex
# 433                                   Hippocampus tail  subcortex
# 408            Thalamus, lateral ventro-posterior part  subcortex
# 446                                       Caudate tail  subcortex
# 428                  Hippocampus head, medial division  subcortex
# 447                          Amygdala, lateral nucleus  subcortex
# 439                      Putamen, ventro-anterior part  subcortex
# 438              Thalamus, lateral dorso-anterior part  subcortex
# 450                           Nucleus Accumbens, shell  subcortex
# 453                            Pallidum, anterior part  subcortex
# 422                     Thalamus, dorso-posterior part  subcortex
# 440                       Putamen, dorso-anterior part  subcortex
#
#              component hemisphere  n_subjects  n_athlete  n_learner  ...  \
# 425           Pallidum          R       198.0       67.0      131.0  ...
# 432   Hippocampus body          L       198.0       67.0      131.0  ...
# 424  Nucleus Accumbens          R       198.0       67.0      131.0  ...
# 444            Caudate          L       198.0       67.0      131.0  ...
# 405   Hippocampus body          R       198.0       67.0      131.0  ...
# 417            Caudate          R       198.0       67.0      131.0  ...
# 410           Thalamus          R       198.0       67.0      131.0  ...
# 400   Hippocampus head          R       198.0       67.0      131.0  ...
# 402           Thalamus          R       198.0       67.0      131.0  ...
# 431   Hippocampus head          L       198.0       67.0      131.0  ...
# 415            Putamen          R       198.0       67.0      131.0  ...
# 443            Caudate          L       198.0       67.0      131.0  ...
# 401   Hippocampus head          R       198.0       67.0      131.0  ...
# 449           Thalamus          L       198.0       67.0      131.0  ...
# 430           Thalamus          L       198.0       67.0      131.0  ...
# 436           Thalamus          L       198.0       67.0      131.0  ...
# 441            Putamen          L       198.0       67.0      131.0  ...
# 437           Thalamus          L       198.0       67.0      131.0  ...
# 406   Hippocampus tail          R       198.0       67.0      131.0  ...
# 445       Caudate body          L       198.0       67.0      131.0  ...
# 452           Pallidum          L       198.0       67.0      131.0  ...
# 429           Thalamus          L       198.0       67.0      131.0  ...
# 423  Nucleus Accumbens          R       198.0       67.0      131.0  ...
# 419       Caudate tail          R       198.0       67.0      131.0  ...
# 434           Thalamus          L       198.0       67.0      131.0  ...
# 451  Nucleus Accumbens          L       198.0       67.0      131.0  ...
# 420           Amygdala          R       198.0       67.0      131.0  ...
# 404   Hippocampus head          R       198.0       67.0      131.0  ...
# 413            Putamen          R       198.0       67.0      131.0  ...
# 421           Amygdala          R       198.0       67.0      131.0  ...
# 418       Caudate body          R       198.0       67.0      131.0  ...
# 407           Thalamus          R       198.0       67.0      131.0  ...
# 442            Putamen          L       198.0       67.0      131.0  ...
# 448           Amygdala          L       198.0       67.0      131.0  ...
# 427   Hippocampus head          L       198.0       67.0      131.0  ...
# 412            Putamen          R       198.0       67.0      131.0  ...
# 435           Thalamus          L       198.0       67.0      131.0  ...
# 414            Putamen          R       198.0       67.0      131.0  ...
# 416            Caudate          R       198.0       67.0      131.0  ...
# 411           Thalamus          R       198.0       67.0      131.0  ...
# 426           Pallidum          R       198.0       67.0      131.0  ...
# 409           Thalamus          R       198.0       67.0      131.0  ...
# 403           Thalamus          R       198.0       67.0      131.0  ...
# 433   Hippocampus tail          L       198.0       67.0      131.0  ...
# 408           Thalamus          R       198.0       67.0      131.0  ...
# 446       Caudate tail          L       198.0       67.0      131.0  ...
# 428   Hippocampus head          L       198.0       67.0      131.0  ...
# 447           Amygdala          L       198.0       67.0      131.0  ...
# 439            Putamen          L       198.0       67.0      131.0  ...
# 438           Thalamus          L       198.0       67.0      131.0  ...
# 450  Nucleus Accumbens          L       198.0       67.0      131.0  ...
# 453           Pallidum          L       198.0       67.0      131.0  ...
# 419     Climbing
# 434     Climbing
# 451     Climbing
# 420     Climbing
# 404     Climbing
# 413     Climbing
# 421     Climbing
# 418     Climbing
# 407     Climbing
# 442     Climbing
# 448     Climbing
# 427     Climbing
# 412     Climbing
# 435     Climbing
# 414     Climbing
# 416     Climbing
# 411     Climbing
# 426     Climbing
# 409     Climbing
# 403     Climbing
# 433     Climbing
# 408     Climbing
# 446     Climbing
# 428     Climbing
# 447     Climbing
# 439     Climbing
# 438     Climbing
# 450     Climbing
# 453     Climbing
# 422     Climbing
# 440     Climbing
#
# [54 rows x 90 columns]

# %%
plotting.plot_stat_map(
    atlas_mod,
    title="Climbing - Interaction term (MD)",
    threshold=0,
    display_mode="mosaic",
    cut_coords=10,
)
# Out:
# /home/galkepler/Projects/athletes_brain/venv/lib/python3.12/site-packages/nilearn/plotting/img_plotting.py:1416: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   safe_get_data(stat_map_img, ensure_finite=True),

# %%
from scipy.stats import ttest_1samp, ttest_rel

diff_results = {}

for metric, df in metric_data.items():
    diff_results[metric] = {}
    # if metric != "adc":
    #     continue
    for group in ["all", "Climbing", "Bjj"]:
        if group == "all":
            key = "athletes"
            group_df = df.copy()
        else:
            key = group.lower()
            group_df = df[df["group"] == group]
        cs_stats = output_dir.parent / "fig1" / metric / f"{key}_vs_controls" / "stats.csv"
        cs_stats = pd.read_csv(cs_stats)
        significant_rois = cs_stats[cs_stats["p_value_corrected"] < 0.05]
        diff_stats = parcels.copy()

        for i in significant_rois.index:
            roi_df = group_df[
                group_df[config.REGION_COL] == significant_rois.loc[i, config.REGION_COL]
            ]
            roi_df.loc[roi_df["subject_code"].str.contains("BJJC"), "condition"] = "Ccontrol"
            roi_df.loc[roi_df["subject_code"].str.contains("CLMC"), "condition"] = "Ccontrol"
            tidy = prepare_roi_longitudinal(roi_df, cfg)
            tidy = tidy[tidy["time_months"] < 12 * 2]
            d = tidy.loc[tidy["tp_label"].isin(["pre", "post"])].copy()
            d = d.loc[tidy["sport"].str.lower().isin(["bjj", "climbing"])].copy()
            has_both = d.groupby("subject_code")["tp_label"].transform(
                lambda s: {"pre", "post"}.issubset(set(s))
            )
            d = d[has_both].copy()
            d_before = d[d["tp_label"] == "pre"].set_index("subject_code")
            d_after = d[d["tp_label"] == "post"].set_index("subject_code")

            d_learners_before = d_before[d_before["condition"] == "Learner"]
            d_athletes_before = d_before[d_before["condition"] != "Learner"]
            d_learners_after = d_after[d_after["condition"] == "Learner"]
            d_athletes_after = d_after[d_after["condition"] != "Learner"]

            t, p = ttest_rel(
                d_learners_after["y"], d_learners_before.loc[d_learners_after.index, "y"]
            )
            diff_stats.loc[i, "t_learners"] = t
            diff_stats.loc[i, "p_learners"] = p
            t, p = ttest_rel(
                d_athletes_after["y"], d_athletes_before.loc[d_athletes_after.index, "y"]
            )
            diff_stats.loc[i, "t_athletes"] = t
            diff_stats.loc[i, "p_athletes"] = p

            # df_diff = d_after.copy()
            # df_diff["delta"] = df_diff["y"] - d_before["y"].values
            # df_diff["relative_delta"] = df_diff["delta"] / d_before["y"].values
            # df_diff["delta_days"] = (d_after["scan_dt"] - d_before["scan_dt"].values).dt.days

            # df_learners = df_diff[df_diff["condition"] == "Learner"]
            # df_athletes = df_diff[df_diff["condition"] != "Learner"]
            # t, p = ttest_1samp(df_learners["delta"], 0)
            # diff_stats.loc[i, "t_learner"] = t
            # diff_stats.loc[i, "p_learner"] = p
            # t, p = ttest_1samp(df_athletes["delta"], 0)
            # diff_stats.loc[i, "t_athlete"] = t
            # diff_stats.loc[i, "p_athlete"] = p
        for pcol in ["p_learners", "p_athletes"]:
            qcol = pcol.replace("p_", "q_")
            mask = diff_stats[pcol].notna()
            if mask.any():
                diff_stats.loc[mask, qcol] = multipletests(
                    diff_stats.loc[mask, pcol], method="fdr_bh"
                )[1]
        # multiple tests

        diff_results[metric][group.lower()] = diff_stats
        # break
    # break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 24
#      22 roi_df.loc[roi_df["subject_code"].str.contains("BJJC"), "condition"] = "Ccontrol"
#      23 roi_df.loc[roi_df["subject_code"].str.contains("CLMC"), "condition"] = "Ccontrol"
# ---> 24 tidy = prepare_roi_longitudinal(roi_df, cfg)
#      25 tidy = tidy[tidy["time_months"] < 12 * 2]
#      26 d = tidy.loc[tidy["tp_label"].isin(["pre", "post"])].copy()
#
# File ~/Projects/athletes_brain/notebooks/learners/roi_prep.py:121, in prepare_roi_longitudinal(df, config)
#     118 d["time_months"] = d["time_days"] / 30.4375
#     120 # Role & sport
# --> 121 d["condition"] = d.apply(
#     122     _infer_role,
#     123     axis=1,
#     124     condition_col=config.condition_col,
#     125     learner_flag_col=config.learner_flag_col,
#     126     labels=config.role_labels,
#     127 )
#     128 d["sport"] = (
#     129     d[config.group_col].apply(_infer_sport) if config.group_col in d.columns else "None"
#     130 )
#     132 # Covariates (if present)
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/apply.py:1079, in FrameApply.apply_series_generator(self)
#    1076 results = {}
#    1078 with option_context("mode.chained_assignment", None):
# -> 1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
#    1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/apply.py:1249, in FrameColumnApply.series_generator(self)
#    1247 @property
#    1248 def series_generator(self) -> Generator[Series, None, None]:
# -> 1249     values = self.values
#    1250     values = ensure_wrapped_if_datetimelike(values)
#    1251     assert len(values) > 0
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/apply.py:862, in FrameApply.values(self)
#     860 @cache_readonly
#     861 def values(self):
# --> 862     return self.obj.values
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/frame.py:12664, in DataFrame.values(self)
#   12590 @property
#   12591 def values(self) -> np.ndarray:
#   12592     """
#   12593     Return a Numpy representation of the DataFrame.
#   12594
#    (...)  12662            ['monkey', nan, None]], dtype=object)
#   12663     """
# > 12664     return self._mgr.as_array()
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:1735, in BlockManager._interleave(self, dtype, na_value)
#    1733 for blk in self.blocks:
#    1734     rl = blk.mgr_locs
# -> 1735     arr = blk.get_values(dtype)
#    1736     result[rl.indexer] = arr
#    1737     itemmask[rl.indexer] = 1
#
# File ~/Projects/athletes_brain/venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:2588, in NumpyBlock.get_values(self, dtype)
#    2586 def get_values(self, dtype: DtypeObj | None = None) -> np.ndarray:
#    2587     if dtype == _dtype_obj:
# -> 2588         return self.values.astype(_dtype_obj)
#    2589     return self.values
#
# KeyboardInterrupt:

# %%
import nibabel as nib
from nilearn import plotting

metric = "gm_vol"
metric_vis = {"adc": "MD", "gm_vol": "GM Volume"}
sport = "all"
fdr_corrected = True

for sport in ["all", "climbing", "bjj"]:
    for cond in ["learners", "athletes"]:
        for metric in metrics:
            metric_dir = output_dir / sport / "athletes_guided" / metric / cond
            metric_dir.mkdir(parents=True, exist_ok=True)
            vis_df = diff_results[metric][sport.lower()]
            vis_df.index = parcels.index

            vis_config = Fig1Config()
            vis_config.VMIN = vmin
            vis_config.VMAX = vmax

            #     break
            # break
            plotter = BrainPlotter(vis_config)

            plotter.plot_single_metric(
                results_df=vis_df,
                metric_key=f"{metric}_{sport}_{cond}",
                output_dir=metric_dir,
                p_column=f"p_{cond}" if fdr_corrected else f"q_{cond}",
                value_column=f"t_{cond}",
            )
            plt.close("all")
    #         break
    #     break
    # break
# Out:
# 2025-08-27 17:31:17.636 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for gm_vol_all_learners
# 2025-08-27 17:31:17.636 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:17.639 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:17.640 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_learners
# 2025-08-27 17:31:17.659 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:17.659 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:17.671 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:18.539 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/learners/left_gm_vol_all_learners.png
# 2025-08-27 17:31:18.540 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-27 17:31:19.409 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/learners/right_gm_vol_all_learners.png
# 2025-08-27 17:31:19.409 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-27 17:31:19.409 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-27 17:31:19.891 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/learners/subcort_gm_vol_all_learners_L.png
# 2025-08-27 17:31:19.891 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-27 17:31:20.626 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/learners/subcort_gm_vol_all_learners_R.png
# 2025-08-27 17:31:20.626 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for gm_vol_all_learners
# 2025-08-27 17:31:20.627 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for adc_all_learners
# 2025-08-27 17:31:20.627 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:20.629 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:20.629 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_learners
# 2025-08-27 17:31:20.641 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:20.641 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:20.648 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:21.558 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/learners/left_adc_all_learners.png
# 2025-08-27 17:31:21.559 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-27 17:31:22.465 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/learners/right_adc_all_learners.png
# 2025-08-27 17:31:22.465 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-27 17:31:22.465 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-27 17:31:22.941 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/learners/subcort_adc_all_learners_L.png
# 2025-08-27 17:31:22.941 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-27 17:31:23.668 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/learners/subcort_adc_all_learners_R.png
# 2025-08-27 17:31:23.668 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for adc_all_learners
# 2025-08-27 17:31:23.669 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for gm_vol_all_athletes
# 2025-08-27 17:31:23.669 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:23.671 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:23.671 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_athletes
# 2025-08-27 17:31:23.683 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:23.683 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:23.690 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:24.625 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/athletes/left_gm_vol_all_athletes.png
# 2025-08-27 17:31:24.626 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-27 17:31:25.464 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/athletes/right_gm_vol_all_athletes.png
# 2025-08-27 17:31:25.464 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-27 17:31:25.464 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-27 17:31:25.950 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/athletes/subcort_gm_vol_all_athletes_L.png
# 2025-08-27 17:31:25.950 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-27 17:31:26.669 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/gm_vol/athletes/subcort_gm_vol_all_athletes_R.png
# 2025-08-27 17:31:26.669 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for gm_vol_all_athletes
# 2025-08-27 17:31:26.670 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for adc_all_athletes
# 2025-08-27 17:31:26.670 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:26.672 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:26.672 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_athletes
# 2025-08-27 17:31:26.684 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:26.684 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:26.691 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:27.581 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/athletes/left_adc_all_athletes.png
# 2025-08-27 17:31:27.582 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-27 17:31:28.474 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/athletes/right_adc_all_athletes.png
# 2025-08-27 17:31:28.474 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-27 17:31:28.474 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-27 17:31:28.980 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/athletes/subcort_adc_all_athletes_L.png
# 2025-08-27 17:31:28.981 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-27 17:31:29.721 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/all/athletes_guided/adc/athletes/subcort_adc_all_athletes_R.png
# 2025-08-27 17:31:29.721 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for adc_all_athletes
# 2025-08-27 17:31:29.722 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for gm_vol_climbing_learners
# 2025-08-27 17:31:29.722 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:29.724 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:29.724 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_learners
# 2025-08-27 17:31:29.736 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:29.736 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:29.743 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:30.660 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/climbing/athletes_guided/gm_vol
| SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for adc_bjj_learners
# 2025-08-27 17:31:48.549 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for gm_vol_bjj_athletes
# 2025-08-27 17:31:48.549 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:48.551 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:48.551 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_athletes
# 2025-08-27 17:31:48.563 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:48.563 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:48.570 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:49.449 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/gm_vol/athletes/left_gm_vol_bjj_athletes.png
# 2025-08-27 17:31:49.449 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-27 17:31:50.411 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/gm_vol/athletes/right_gm_vol_bjj_athletes.png
# 2025-08-27 17:31:50.411 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-27 17:31:50.411 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-27 17:31:50.879 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/gm_vol/athletes/subcort_gm_vol_bjj_athletes_L.png
# 2025-08-27 17:31:50.879 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-27 17:31:51.588 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/gm_vol/athletes/subcort_gm_vol_bjj_athletes_R.png
# 2025-08-27 17:31:51.588 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for gm_vol_bjj_athletes
# 2025-08-27 17:31:51.588 | INFO     | athletes_brain.fig1.brain_visualization:plot_single_metric:276 - Creating brain plots for adc_bjj_athletes
# 2025-08-27 17:31:51.588 | INFO     | athletes_brain.fig1.brain_visualization:setup_surfaces:30 - Setting up brain surfaces and parcellations
# 2025-08-27 17:31:51.590 | SUCCESS  | athletes_brain.fig1.brain_visualization:setup_surfaces:39 - Brain surfaces and parcellations loaded successfully
# 2025-08-27 17:31:51.590 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:57 - Preparing value maps for t_athletes
# 2025-08-27 17:31:51.602 | INFO     | athletes_brain.fig1.brain_visualization:prepare_value_maps:97 - Prepared maps with 200 LH, 200 RH, and 54 subcortical regions
# 2025-08-27 17:31:51.602 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:121 - Creating cortical surface plots
# 2025-08-27 17:31:51.609 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting left hemisphere
# 2025-08-27 17:31:52.533 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved left hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/adc/athletes/left_adc_bjj_athletes.png
# 2025-08-27 17:31:52.534 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:143 - Plotting right hemisphere
# 2025-08-27 17:31:53.437 | INFO     | athletes_brain.fig1.brain_visualization:plot_cortical_surface:177 - Saved right hemisphere plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/adc/athletes/right_adc_bjj_athletes.png
# 2025-08-27 17:31:53.437 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:193 - Creating subcortical plots
# 2025-08-27 17:31:53.438 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting L subcortical regions
# 2025-08-27 17:31:53.913 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved L subcortical plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/adc/athletes/subcort_adc_bjj_athletes_L.png
# 2025-08-27 17:31:53.913 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:196 - Plotting R subcortical regions
# 2025-08-27 17:31:54.637 | INFO     | athletes_brain.fig1.brain_visualization:plot_subcortical:213 - Saved R subcortical plot to /media/storage/phd/athletes_brain/figures/learners/bjj/athletes_guided/adc/athletes/subcort_adc_bjj_athletes_R.png
# 2025-08-27 17:31:54.637 | SUCCESS  | athletes_brain.fig1.brain_visualization:plot_single_metric:294 - Completed brain plots for adc_bjj_athletes

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
vis_config = Fig1Config()

# cmaps = config.get_colormaps()
# cmap = cmaps["weighted"]
vis_config.COLORMAP = "coolwarm"

vis_config.VMIN = -3
vis_config.VMAX = 3
plotter = BrainPlotter(vis_config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vis_config = Fig1Config()
#       3 # cmaps = config.get_colormaps()
#       4 # cmap = cmaps["weighted"]
#       5 vis_config.COLORMAP = "coolwarm"
#
# NameError: name 'Fig1Config' is not defined

# %%
effect = "factor_interaction"
is_learner = effect.startswith("L")

plotter.plot_single_metric(
    results_df=stats,
    metric_key=effect,
    output_dir=output_dir,
    p_column=f"{effect}_p" if not is_learner else effect.replace("beta", "p"),
    value_column=f"{effect}_z" if not is_learner else effect.replace("beta", "z"),
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
